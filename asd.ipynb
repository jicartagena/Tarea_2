# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Ac = [-31.8, 71.8, -6.58, -48.1, -27.7]
Coef = [2.32, -5.88, -1.29, 2.32, -2.7]

sns.scatterplot(x=Ac, y=Coef)

plt.xlabel('Aceleración Angular')
plt.ylabel('Coeficente')


plt.show()
